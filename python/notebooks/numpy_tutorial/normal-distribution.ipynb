# %% [markdown]
# # NumPy Tutorial
#
# https://www.w3schools.com/python/numpy/

# %% [markdown]
# ## Normal Distribution
#
# Use `random.normal()` to get a normal distribution. Specify these three parameters:
# - `loc` = mean
# - `scale` = the standard deviation
# - `size` = the shape of the returned array

# %%
import numpy as np
from configurations import printer

my_2_by_3_of_z = np.random.normal(loc=0, scale=1, size = (2, 3))

printer(my_2_by_3_of_z)

my_2_by_3_of_normal = np.random.normal(loc=1, scale=2, size=(2, 3))

printer(my_2_by_3_of_normal)
# Out:
# [[-1.55380628  0.05929785  1.73274776]
#  [-1.19881369 -1.26461179  1.00880317]]
# [[ 1.70047325  1.53274399  0.64096   ]
#  [ 0.83726891 -0.54899753  3.70898403]]

# %% [markdown]
# ### Visualization of Normal distribution

# %%
import numpy as np
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt
from configurations import logger

plt.style.use('my_mpl_stylesheet.mpltstyle')

logger.warning(
    'Seaborn does not seem to export a stub to help linters with type hints\n'
    'so I am explicitly disabling type hints on those lines.'
)

logger.warning(
    'Matplotlib does not seem to have types set up for linters.\n'
    'So I am explicitly disabling type hints on those lines.'
)

def plot_normal(size: int = 10, loc: float = 0, scale: float = 1) -> None:
    my_normal = np.random.normal(loc=loc, scale=scale, size=size)

    sns.histplot( # type: ignore
        my_normal,
        ax=plt.subplots()[1], # type: ignore
        stat='probability',
        kde=True,
        edgecolor='None',
        )

    plt.title( # type: ignore
        label=f'{size:,} samples from a normal distribution with\n'
        fr'$\mu$={loc:,.0f} and $\sigma$={scale:.1f}',
        family='serif'
        )

    plt.xlabel(xlabel='Value of sample', family='sans-serif') #type: ignore
    
plot_normal(size=1_000)
# Out:
# 2023-08-21 07:39:05
# 	Logger: numpy-tutorial Module: 3728875949 Function: <module> File: 3728875949.py Line: 8
# WARNING:
# Seaborn does not seem to export a stub to help linters with type hints
# so I am explicitly disabling type hints on those lines.
#
#
# 2023-08-21 07:39:05
# 	Logger: numpy-tutorial Module: 3728875949 Function: <module> File: 3728875949.py Line: 13
# WARNING:
# Matplotlib does not seem to have types set up for linters.
# So I am explicitly disabling type hints on those lines.

# %% [markdown]
# Observe how using more samples makes the plot look more like the underlying distribution.

# %%
import numpy as np
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt
from configurations import logger

plt.style.use('my_mpl_stylesheet.mpltstyle')

logger.warning(
    'Seaborn does not seem to export a stub to help linters with type hints\n'
    'so I am explicitly disabling type hints on those lines.'
)

logger.warning(
    'Matplotlib subplots does not seem to have types set up for linters.\n'
    'So I am explicitly disabling type hints on those lines.'
)

def plot_normal(size: int = 10, loc: float = 0, scale: float = 1) -> None:
    my_normal = np.random.normal(loc=loc, scale=scale, size=size)

    sns.histplot( # type: ignore
        my_normal,
        ax=plt.subplots()[1], # type: ignore
        stat='probability',
        kde=True,
        edgecolor='None',
        )

    plt.title( # type: ignore
        label=f'{size:,} samples from a normal distribution with\n'
        fr'$\mu$={loc:,.0f} and $\sigma$={scale:.1f}',
        family='serif'
        )

    plt.xlabel(xlabel='Value of sample', family='sans-serif') #type: ignore
    
sizes_to_cycle_through = [10, 100, 1_000, 10_000]

for size in sizes_to_cycle_through:
    plot_normal(size=size)
# Out:
# 2023-08-21 07:26:17
# 	Logger: numpy-tutorial Module: 656436034 Function: <module> File: 656436034.py Line: 8
# WARNING:
# Seaborn does not seem to export a stub to help linters with type hints
# so I am explicitly disabling type hints on those lines.
#
#
# 2023-08-21 07:26:17
# 	Logger: numpy-tutorial Module: 656436034 Function: <module> File: 656436034.py Line: 13
# WARNING:
# Matplotlib subplots does not seem to have types set up for linters.
# So I am explicitly disabling type hints on those lines.
